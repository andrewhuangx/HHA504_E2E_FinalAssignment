# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewhuangx/HHA504_E2E_FinalAssignment/blob/main/E2E_Final_Assignment_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Packages

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 990 kB/s
# ...

# %%
pip install cryptography
# Out:
# ...
#      |████████████████████████████████| 3.6 MB 7.5 MB/s
# ...

# %%
# !pip install cryptography

# %% [markdown]
# ## Connect to SQL Instance

# %%
MYSQL_HOSTNAME = '52.168.141.66'
MYSQL_USER = 'dba'
MYSQL_PASSWORD = 'ahi2021'
MYSQL_DATABASE = 'e2e'

# %%
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}:3306/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
print (engine.table_names)
# Out:
# <bound method Engine.table_names of Engine(mysql+pymysql://dba:***@52.168.141.66:3306/e2e)>

# %% [markdown]
# ## Load CSV

# %%
csvfile = pd.read_csv('https://raw.githubusercontent.com/andrewhuangx/HHA504_E2E_FinalAssignment/main/H1N1_Flu_Vaccines.csv')

# %%
csvfile
# Out:
#        respondent_id  h1n1_concern  ...  h1n1_vaccine  seasonal_vaccine
# 0                  0           1.0  ...             0                 0
# 1                  1           3.0  ...             0                 1
# 2                  2           1.0  ...             0                 0
# 3                  3           1.0  ...             0                 1
# 4                  4           2.0  ...             0                 0
# ...              ...           ...  ...           ...               ...
# 26702          26702           2.0  ...             0                 0
# 26703          26703           1.0  ...             0                 0
# 26704          26704           2.0  ...             0                 1
# 26705          26705           1.0  ...             0                 0
# 26706          26706           0.0  ...             0                 0
#
# [26707 rows x 38 columns]

# %% [markdown]
# ## Upload CSV to MySQL Database

# %%
csvfile = pd.read_csv('https://raw.githubusercontent.com/andrewhuangx/HHA504_E2E_FinalAssignment/main/H1N1_Flu_Vaccines.csv')

# %%
TABLENAME = 'H1N1'

# %%
csvfile.to_sql(TABLENAME, con=engine, if_exists='append')
